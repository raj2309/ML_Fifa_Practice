# %%
# The code was removed by Watson Studio for sharing.
# Out:
#    Wage (€)  Value (€)               Name  Age  \
# 0    565000   95500000  Cristiano Ronaldo   32
# 1    565000  105000000           L. Messi   30
# 2    280000  123000000             Neymar   25
# 3    510000   97000000          L. Suárez   30
# 4    230000   61000000           M. Neuer   31
#
#                                              Photo Nationality  \
# 0   https://cdn.sofifa.org/48/18/players/20801.png    Portugal
# 1  https://cdn.sofifa.org/48/18/players/158023.png   Argentina
# 2  https://cdn.sofifa.org/48/18/players/190871.png      Brazil
# 3  https://cdn.sofifa.org/48/18/players/176580.png     Uruguay
# 4  https://cdn.sofifa.org/48/18/players/167495.png     Germany
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/38.png       94         94
# 1  https://cdn.sofifa.org/flags/52.png       93         93
# 2  https://cdn.sofifa.org/flags/54.png       92         94
# ...

# %%
df_data_0.columns
# Out:
# Index(['Wage (€)', 'Value (€)', 'Name', 'Age', 'Photo', 'Nationality', 'Flag',
#        'Overall', 'Potential', 'Club', 'Club Logo', 'Special', 'Acceleration',
#        'Aggression', 'Agility', 'Balance', 'Ball control', 'Composure',
#        'Crossing', 'Curve', 'Dribbling', 'Finishing', 'Free kick accuracy',
#        'GK diving', 'GK handling', 'GK kicking', 'GK positioning',
#        'GK reflexes', 'Heading accuracy', 'Interceptions', 'Jumping',
#        'Long passing', 'Long shots', 'Marking', 'Penalties', 'Positioning',
#        'Reactions', 'Short passing', 'Shot power', 'Sliding tackle',
#        'Sprint speed', 'Stamina', 'Standing tackle', 'Strength', 'Vision',
#        'Volleys', 'CAM', 'CB', 'CDM', 'CF', 'CM', 'ID', 'LAM', 'LB', 'LCB',
#        'LCM', 'LDM', 'LF', 'LM', 'LS', 'LW', 'LWB', 'Preferred Positions',
#        'RAM', 'RB', 'RCB', 'RCM', 'RDM', 'RF', 'RM', 'RS', 'RW', 'RWB', 'ST'],
#       dtype='object')

# %%
import numpy as np

# %%
df_data_0.describe()
# Out:
#             Wage (€)     Value (€)           Age       Overall     Potential  \
# count   17981.000000  1.798100e+04  17981.000000  17981.000000  17981.000000
# mean    11546.966242  2.385390e+06     25.144541     66.247984     71.190813
# std     23080.000139  5.353970e+06      4.614272      6.987965      6.102199
# min         0.000000  0.000000e+00     16.000000     46.000000     46.000000
# 25%      2000.000000  3.000000e+05     21.000000     62.000000     67.000000
# 50%      4000.000000  6.750000e+05     25.000000     66.000000     71.000000
# 75%     12000.000000  2.100000e+06     28.000000     71.000000     75.000000
# max    565000.000000  1.230000e+08     47.000000     94.000000     94.000000
#
#             Special  Acceleration    Aggression       Agility       Balance  \
# count  17981.000000  17897.000000  17913.000000  17910.000000  17924.000000
# mean    1594.095100     64.576521     55.791492     63.333613     63.803894
# ...

# %%
df_data_0.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17981 entries, 0 to 17980
# Data columns (total 74 columns):
# Wage (€)               17981 non-null int64
# Value (€)              17981 non-null int64
# Name                   17981 non-null object
# Age                    17981 non-null int64
# Photo                  17981 non-null object
# Nationality            17981 non-null object
# Flag                   17981 non-null object
# Overall                17981 non-null int64
# Potential              17981 non-null int64
# Club                   17733 non-null object
# Club Logo              17981 non-null object
# Special                17981 non-null int64
# Acceleration           17897 non-null float64
# Aggression             17913 non-null float64
# Agility                17910 non-null float64
# Balance                17924 non-null float64
# Ball control           17840 non-null float64
# Composure              17887 non-null float64
# ...

# %%
df_data_0.rename(columns= {'Wage (€)' : 'Wage'}, inplace=True)
df_data_0.head()
# Out:
#      Wage  Value (€)               Name  Age  \
# 0  565000   95500000  Cristiano Ronaldo   32
# 1  565000  105000000           L. Messi   30
# 2  280000  123000000             Neymar   25
# 3  510000   97000000          L. Suárez   30
# 4  230000   61000000           M. Neuer   31
#
#                                              Photo Nationality  \
# 0   https://cdn.sofifa.org/48/18/players/20801.png    Portugal
# 1  https://cdn.sofifa.org/48/18/players/158023.png   Argentina
# 2  https://cdn.sofifa.org/48/18/players/190871.png      Brazil
# 3  https://cdn.sofifa.org/48/18/players/176580.png     Uruguay
# 4  https://cdn.sofifa.org/48/18/players/167495.png     Germany
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/38.png       94         94
# 1  https://cdn.sofifa.org/flags/52.png       93         93
# 2  https://cdn.sofifa.org/flags/54.png       92         94
# 3  https://cdn.sofifa.org/flags/60.png       92         92
# ...

# %%
df_data_0.rename(columns= {'Value (€)' : 'Value'}, inplace=True)
df_data_0.head()
# Out:
#      Wage      Value               Name  Age  \
# 0  565000   95500000  Cristiano Ronaldo   32
# 1  565000  105000000           L. Messi   30
# 2  280000  123000000             Neymar   25
# 3  510000   97000000          L. Suárez   30
# 4  230000   61000000           M. Neuer   31
#
#                                              Photo Nationality  \
# 0   https://cdn.sofifa.org/48/18/players/20801.png    Portugal
# 1  https://cdn.sofifa.org/48/18/players/158023.png   Argentina
# 2  https://cdn.sofifa.org/48/18/players/190871.png      Brazil
# 3  https://cdn.sofifa.org/48/18/players/176580.png     Uruguay
# 4  https://cdn.sofifa.org/48/18/players/167495.png     Germany
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/38.png       94         94
# 1  https://cdn.sofifa.org/flags/52.png       93         93
# 2  https://cdn.sofifa.org/flags/54.png       92         94
# 3  https://cdn.sofifa.org/flags/60.png       92         92
# ...

# %%
import numpy as np

# %%
bins=np.linspace(min(df_data_0['Wage']), max(df_data_0['Wage']), 4)

# %%
group_names={"Low", "Medium", "High"}

# %%
import matplotlib.pyplot as plt

# %%
y=df_data_0['Wage']

# %%
x=df_data_0['Value']

# %%
plt.scatter(x,y)
plt.title("Wage vs Value")
plt.xlabel("Value")
plt.ylabel("Wage")
# Out:
# Text(0, 0.5, 'Wage')

# %%
df1=df_data_0.head(40)
df1
# Out:
#       Wage      Value               Name  Age  \
# 0   565000   95500000  Cristiano Ronaldo   32
# 1   565000  105000000           L. Messi   30
# 2   280000  123000000             Neymar   25
# 3   510000   97000000          L. Suárez   30
# 4   230000   61000000           M. Neuer   31
# 5   355000   92000000     R. Lewandowski   28
# 6   215000   64500000             De Gea   26
# 7   295000   90500000          E. Hazard   26
# 8   340000   79000000           T. Kroos   27
# 9   275000   77000000         G. Higuaín   29
# 10  310000   52000000       Sergio Ramos   31
# 11  285000   83000000       K. De Bruyne   26
# 12  190000   59000000        T. Courtois   25
# 13  265000   67500000         A. Sánchez   28
# 14  340000   57000000          L. Modrić   31
# 15  370000   69500000            G. Bale   27
# 16  325000   66500000          S. Agüero   29
# 17  225000   38000000       G. Chiellini   32
# 18  110000    4500000          G. Buffon   39
# ...

# %%
a= ((np.asarray(df1['Club'])).reshape(5,8))

# %%
b= ((np.asarray((df1['Wage']))).reshape(5,8))
c= ((np.asarray((df1['Value']))).reshape(5,8))

# %%
print(a)
print(b)
print(c)
# Out:
# [['Real Madrid CF' 'FC Barcelona' 'Paris Saint-Germain' 'FC Barcelona'
#   'FC Bayern Munich' 'FC Bayern Munich' 'Manchester United' 'Chelsea']
#  ['Real Madrid CF' 'Juventus' 'Real Madrid CF' 'Manchester City'
#   'Chelsea' 'Arsenal' 'Real Madrid CF' 'Real Madrid CF']
#  ['Manchester City' 'Juventus' 'Juventus' 'Juventus' 'Atlético Madrid'
#   'Atlético Madrid' 'FC Bayern Munich' 'Borussia Dortmund']
#  ['Milan' 'FC Bayern Munich' 'Atlético Madrid' 'FC Bayern Munich'
#   'Arsenal' 'Tottenham Hotspur' 'Paris Saint-Germain' 'Manchester United']
#  ['FC Bayern Munich' 'Chelsea' 'Paris Saint-Germain' 'Manchester United'
#   'Tottenham Hotspur' 'FC Bayern Munich' 'Paris Saint-Germain'
#   'Real Madrid CF']]
# [[565000 565000 280000 510000 230000 355000 215000 295000]
#  [340000 275000 310000 285000 190000 265000 340000 370000]
#  [325000 225000 110000 215000  82000 150000 225000 165000]
#  [210000 215000 125000 215000 265000 165000 175000 240000]
# ...

# %%
df_test=df1[['Club', 'Value', 'Wage']]

# %%
df_grp=df_test.groupby(['Club', 'Wage'], as_index=False).mean()

# %%
df_pivot=df_grp.pivot(index='Club', columns='Wage')

# %%
plt.pcolor(df_pivot, cmap="RdBu")
plt.colorbar()
plt.show()

# %%
import seaborn as sns

# %% [markdown]
# ### using replot to check correlation between Age and value

# %%
sns.regplot(x="Age", y="Value", data=df1)
plt.ylim(0,)
# Out:
# (0, 129221939.99189743)

# %% [markdown]
# ###### line decreases, shows a strong negative correlation

# %% [markdown]
# ### Using regplot to find a correlation between value and wage

# %%
sns.regplot(x="Value", y="Wage", data=df1)
plt.ylim(0,)
# Out:
# (0, 607026.4051098512)

# %% [markdown]
# ###### Line increases, shows a strong positive correlation

# %%
sns.boxplot(x="Age", y="Wage", data=df1)

# %%
from scipy import stats

# %%
pearson_coef=stats.pearsonr(df1['Age'], df1['Value'])
pearson_coef
# Out:
# (-0.5453533846520893, 0.00027357178858069945)

# %%
from sklearn import datasets, linear_model
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
lm=linear_model.LinearRegression(normalize= True)

# %%
X=df1[['Age']]

# %%
Y=df1['Value']

# %%
lm.fit(X, Y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=True)

# %%
Yhat=lm.predict(X)

# %%
lm.intercept_
# Out:
# 172467194.5701357

# %%
lm.coef_
# Out:
# array([-3876696.83257918])

# %%
plt.scatter(X,Y)
plt.plot(X, lm.predict(X), color= 'Red')
plt.show()

# %%
sns.residplot(df1[['Age']], df1['Value'])

# %%
ax1=sns.distplot(df1[['Value']], hist= False, color="r", label="Actual")

# %%
ax=sns.distplot(Yhat, hist=False, color="b", label="fitted")

# %%
lm.score(X, Y)
# Out:
# 0.29741031415148966
